# %% [markdown]
# # Check the pickle files in resources folder

# %% [markdown]
# ## Discover file article l3

# %%
import pickle
import sys
from pathlib import Path
import pandas as pd

ROOT_DIR = Path().resolve()   # adjust if needed
sys.path.append(str(ROOT_DIR))


df = pd.read_pickle(ROOT_DIR / 'resources' / 'articles_l3.pkl')

df.head()
# Out:
#               title_en                                            text_en  \
# 0            Hammurabi  Hammurabi (; Akkadian: 𒄩𒄠𒈬𒊏𒁉 Ḫâmmurapi; c. 181...
# 1          Ramesses II  Ramesses II (; Ancient Egyptian: rꜥ-ms-sw, Rīꜥ...
# 2      Cyrus the Great  Cyrus II of Persia (Old Persian: 𐎤𐎢𐎽𐎢𐏁 Kūruš; ...
# 3  Alexander the Great  Alexander III of Macedon (Ancient Greek: Ἀλέξα...
# 4               Ashoka  Ashoka (; Sanskrit pronunciation: [ɐˈɕo:kɐ], I...
#
#                  title_de                                            text_de  \
# 0  Hammurapi I. (Babylon)  Hammurapi (auch: Hammurabi oder mit Ḫ geschrie...
# 1              Ramses II.  Ramses II., auch Ramses der Große genannt (* u...
# 2               Kyros II.  Kyros II. (altpersisch Kūruš, neupersisch کورو...
# 3     Alexander der Große  Alexander der Große (altgriechisch Ἀλέξανδρος ...
# 4                  Ashoka  Aśoka oder (im englischen Sprachraum) Ashoka (...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title_en        999 non-null    object
#  1   text_en         999 non-null    object
#  2   title_de        975 non-null    object
#  3   text_de         975 non-null    object
#  4   title_fr        983 non-null    object
#  5   text_fr         983 non-null    object
#  6   description_en  998 non-null    object
#  7   aliases_en      999 non-null    object
#  8   description_de  969 non-null    object
#  9   aliases_de      975 non-null    object
#  10  description_fr  969 non-null    object
#  11  aliases_fr      983 non-null    object
# dtypes: object(12)
# memory usage: 93.8+ KB

# %%
df.isnull().sum()
# Out:
# title_en           0
# text_en            0
# title_de          24
# text_de           24
# title_fr          16
# text_fr           16
# description_en     1
# aliases_en         0
# description_de    30
# aliases_de        24
# description_fr    30
# aliases_fr        16
# dtype: int64

# %%
print(df.iloc[0][1])
# Out:
# Hammurabi (; Akkadian: 𒄩𒄠𒈬𒊏𒁉 Ḫâmmurapi; c. 1810 – c. 1750 BC), also spelled Hammurapi, was the sixth Amorite king of the Old Babylonian Empire, reigning from c. 1792 to c. 1750 BC. He was preceded by his father, Sin-Muballit, who abdicated due to failing health. During his reign, he conquered the city-states of Larsa, Eshnunna, and Mari. He ousted Ishme-Dagan I, the king of Assyria, and forced his son Mut-Ashkur to pay tribute, bringing almost all of Mesopotamia under Babylonian rule.
# ...

# %% [markdown]
# ## Discover article l4

# %%
df = pd.read_pickle(ROOT_DIR / 'resources' / 'articles_l4.pkl')

df.head()
# Out:
#            title_en                                            text_en  \
# 0     Julie Andrews  Dame Julie Andrews  (born Julia Elizabeth Well...
# 1     Lauren Bacall  Betty Joan Perske (September 16, 1924 – August...
# 2  Amitabh Bachchan  Amitabh Bachchan (pronounced [əmɪˈt̪ɑːbʱ ˈbətː...
# 3   Brigitte Bardot  Brigitte Anne-Marie Bardot (  brizh-EET bar-DO...
# 4    Ingrid Bergman  Ingrid Bergman (29 August 1915 – 29 August 198...
#
#            title_de                                            text_de  \
# 0     Julie Andrews  Dame Julie Elizabeth Andrews, DBE, bürgerlich ...
# 1     Lauren Bacall  Lauren Bacall [ˌlɔrən bəˈkɔːl] (* 16. Septembe...
# 2  Amitabh Bachchan  Amitabh Bachchan (Hindi, अमिताभ बच्चन, Amitābh...
# 3   Brigitte Bardot  Brigitte Anne-Marie Bardot, kurz Brigitte Bard...
# 4    Ingrid Bergman  Ingrid Bergman (* 29. August 1915 in Stockholm...
#
#            title_fr                                            text_fr  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10011 entries, 0 to 298
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title_en        10011 non-null  object
#  1   text_en         10011 non-null  object
#  2   title_de        9522 non-null   object
#  3   text_de         9522 non-null   object
#  4   title_fr        9773 non-null   object
#  5   text_fr         9773 non-null   object
#  6   description_en  10005 non-null  object
#  7   aliases_en      10011 non-null  object
#  8   description_de  9357 non-null   object
#  9   aliases_de      9507 non-null   object
#  10  description_fr  9252 non-null   object
#  11  aliases_fr      9769 non-null   object
# dtypes: object(12)
# memory usage: 1016.7+ KB

# %%
df.isnull().sum()
# Out:
# title_en            0
# text_en             0
# title_de          489
# text_de           489
# title_fr          238
# text_fr           238
# description_en      6
# aliases_en          0
# description_de    654
# aliases_de        504
# description_fr    759
# aliases_fr        242
# dtype: int64
